# %%
import pandas as pd

# %%
df = pd.read_feather("mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings.feather")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5032 entries, 0 to 5031
# Columns: 24131 entries, 0610005C13Rik to motifs
# dtypes: int16(24130), object(1)
# memory usage: 231.6+ MB

# %%
df.head()
# Out:
#    0610005C13Rik  0610007P14Rik  0610009B22Rik  0610009L18Rik  0610009O20Rik  \
# 0          22934          20741          18567          21462          13956
# 1          15556          22135           5007           1702          19927
# 2          17564          16424          20503          23214          18834
# 3          21875          11565          22729          20586           9900
# 4          16249          16601          21916           9510          12579
#
#    0610010F05Rik  0610010K14Rik  0610012G03Rik  0610030E20Rik  0610031O16Rik  \
# 0          18071          22369          23372          22281           5876
# 1           9365          22668          23253          20640          11361
# 2           8668          22846          23707          15197          11530
# 3          12780          22858          23815          15335          13248
# 4          18880          21843          23756          22004          10343
#
# ...

# %%
df.columns.tolist()
# Out:
# ['0610005C13Rik',
#  '0610007P14Rik',
#  '0610009B22Rik',
#  '0610009L18Rik',
#  '0610009O20Rik',
#  '0610010F05Rik',
#  '0610010K14Rik',
#  '0610012G03Rik',
#  '0610030E20Rik',
#  '0610031O16Rik',
#  '0610037L13Rik',
#  '0610038B21Rik',
#  '0610039H22Rik',
#  '0610039K10Rik',
#  '0610040B10Rik',
#  '0610040F04Rik',
#  '0610040J01Rik',
#  '0610043K17Rik',
#  '1010001N08Rik',
#  '1110002J07Rik',
#  '1110002L01Rik',
#  '1110004E09Rik',
#  '1110004F10Rik',
#  '1110006O24Rik',
#  '1110008F13Rik',
#  '1110008L16Rik',
#  '1110008P14Rik',
#  '1110012L19Rik',
#  '1110015O18Rik',
#  '1110017D15Rik',
#  '1110019D14Rik',
#  '1110020A21Rik',
#  '1110025L11Rik',
#  '1110028F11Rik',
#  '1110028F18Rik',
#  '1110032A03Rik',
#  '1110032F04Rik',
#  '1110034G24Rik',
#  '1110036E04Rik',
#  '1110037F02Rik',
#  '1110038B12Rik',
#  '1110038F14Rik',
#  '1110046J04Rik',
#  '1110051M20Rik',
#  '1110058D11Rik',
#  '1110059E24Rik',
#  '1110059G10Rik',
#  '1110065P20Rik',
#  '1190002N15Rik',
#  '1190003K10Rik',
# ...
